# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
with open('./nightlight.json') as f:
    data = json.load(f)
df = pd.DataFrame(data)
df = df.rename(columns={'key': 'state'})
df.to_csv('NightLights.csv')

# %%
df = pd.read_csv('state_gdp/gdp_raw.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 23 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      28 non-null     object
#  1   1993-94    28 non-null     int64
#  2   1994-95    28 non-null     int64
#  3   1995-96    28 non-null     int64
#  4   1996-97    28 non-null     int64
#  5   1997-98    28 non-null     int64
#  6   1998-99    28 non-null     int64
#  7   1999-2000  28 non-null     int64
#  8   2000-2001  28 non-null     int64
#  9   2001-2002  28 non-null     int64
#  10  2002-2003  28 non-null     int64
#  11  2003-2004  28 non-null     int64
#  12  2004-05    28 non-null     int64
#  13  2005-06    28 non-null     int64
#  14  2006-07    28 non-null     int64
#  15  2007-08    28 non-null     int64
#  16  2008-09    28 non-null     int64
#  17  2009-10    28 non-null     int64
#  18  2010-11    28 non-null     int64
#  19  2011-12    28 non-null     int64
#  20  2012-13    28 non-null     int64
#  21  2013-14    28 non-null     int64
#  22  2014-15    21 non-null     float64
# dtypes: float64(1), int64(21), object(1)
# memory usage: 5.2+ KB

# %%
for i in range(28): plt.plot(df.iloc[i,1:20])
plt.show()
